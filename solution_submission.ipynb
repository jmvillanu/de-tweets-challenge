# %%
import requests

url = "https://advana-challenge-check-api-cr-k4hdbggvoq-uc.a.run.app/data-engineer"
payload = {
    "name": "Juan Villanueva",
    "mail": "juanvillanueva.tabares@gmail.com",
    "github_url": "https://github.com/jmvillanu/de-tweets-challenge.git"
}

response = requests.post(url, json=payload)

if response.status_code == 200: # Check if the request was successful (status code 200)
    print("Solution Submitted!")
    print("Response:", response.text)
else:
    print("Submission failed:", response.status_code)
