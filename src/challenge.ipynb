# %% [markdown]
# # Desafío LATAM Airlines para Ingenieros de Datos

# %% [markdown]
# ## Instrucctiones
#
# 1. Instalar las dependencias con: pip install -r requirements.txt en la terminal, desde la raíz del proyecto
# 2. Correr todas las celdas del notebook

# %% [markdown]
# Se resuelve el primer requerimiento con  función ```q1``` que servirá de línea base para luego hacer las optimizaciones por tiempo de ejecucción y uso de memoria:
#
# > Requerimiento: Obtener las top 10 fechas donde hay más tweets. Mencionar el usuario (username) que más publicaciones tiene por cada uno de esos días.

# %% [markdown]
# ### Nota:
#
# #### La documentación está en construcción. Debido al deadline, inicialmente se desarrollaron los scripts para solucionar el reto y sin demasiados detalles en la documentación. Iré actualizándola para que quede lo más descriptiva posible y de la calidad a la que estoy acostumbrado

# %%
# %%capture
# !pip install -r ../requirements.txt

# %% [markdown]
# ### q1 (Linea Base)
#
# La función definida en q1.py crea dos diccionarios diferentes que se utilizan para obtener el conteo de tweets por fecha y luego el conteo de tweets por username por cada fecha.

# %%
# %load_ext memory_profiler

from q1 import q1
from q1_time import q1_time
from q1_memory import q1_memory
from q2 import q2
from q2_time import q2_time
from q2_memory import q2_memory
from q3_time import q3_time
from q3_memory import q3_memory
# from memory_profiler import profile

file_path = "./data/farmers-protest-tweets-2021-2-4-2.json"
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
q1(file_path)
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %%
# %timeit q1(file_path)
# Out:
# 2.81 s ± 98 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q1(file_path)
# Out:
# peak memory: 73.91 MiB, increment: 2.23 MiB

# %% [markdown]
# ### q1_time (Optimización del tiempo de ejecución)
#
# Optimiza el tiempo de ejecución usando Counter que está hecho en C y están precisamente diseñados para este tipo de tareas.

# %%
q1_time(file_path)
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %%
# %timeit q1_time(file_path)
# Out:
# 3.05 s ± 135 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q1_time(file_path)
# Out:
# peak memory: 72.11 MiB, increment: 0.67 MiB

# %% [markdown]
# ### q1_memoria (Optimizando el uso de memoria)

# %%
q1_memory(file_path)
# Out:
# [('2021-02-12', 'RanbirS00614606'),
#  ('2021-02-13', 'MaanDee08215437'),
#  ('2021-02-17', 'RaaJVinderkaur'),
#  ('2021-02-16', 'jot__b'),
#  ('2021-02-14', 'rebelpacifist'),
#  ('2021-02-18', 'neetuanjle_nitu'),
#  ('2021-02-15', 'jot__b'),
#  ('2021-02-20', 'MangalJ23056160'),
#  ('2021-02-23', 'Surrypuria'),
#  ('2021-02-19', 'Preetm91')]

# %%
# %memit q1_memory(file_path)
# Out:
# peak memory: 72.66 MiB, increment: 0.03 MiB

# %%
# %timeit q1_memory(file_path)
# Out:
# 2.88 s ± 137 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### q2, q2_time y q2_memory
#
# Se usa la librería emoji y Counter de collections para crear un código eficiente tanto en tiempo como en memoria. Las variaciones son pocas entre un código a otro. Sin embargo, en cuanto a la optimización de tiempo, esta tarea se puede paralelizar, lo que reduce drasticamente el tiempo de ejecución. El trade-off es el consumo de memoria, el cual incrementa al paralelizar la tarea.

# %%
q2(file_path)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
# %timeit q2(file_path)
# Out:
# 13.4 s ± 337 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q2(file_path)
# Out:
# peak memory: 70.50 MiB, increment: 0.53 MiB

# %%
q2_time(file_path)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
# %timeit q2_time(file_path)
# Out:
# 4.82 s ± 540 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q2_time(file_path)
# Out:
# peak memory: 905.25 MiB, increment: 297.61 MiB

# %%
q2_memory(file_path)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %%
# %timeit q2_memory(file_path)
# Out:
# 13.4 s ± 614 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q2_memory(file_path)
# Out:
# peak memory: 71.12 MiB, increment: 2.12 MiB

# %% [markdown]
# ### q3_time, q3_memory.
#
# Igual que en el ejercicio anterior, paralelizar la función optimiza el tiempo de ejecución, pero el uso de memoria se dispara. No se crea una función q3 ya que realmente no tendría diferencia notable.

# %%
q3_time(file_path)
# Out:
# [('narendramodi', 2265),
#  ('Kisanektamorcha', 1840),
#  ('RakeshTikaitBKU', 1644),
#  ('PMOIndia', 1427),
#  ('RahulGandhi', 1146),
#  ('GretaThunberg', 1048),
#  ('RaviSinghKA', 1019),
#  ('rihanna', 986),
#  ('UNHumanRights', 962),
#  ('meenaharris', 926)]

# %%
# %timeit q3_time(file_path)
# Out:
# 1.66 s ± 241 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q3_time(file_path)
# Out:
# peak memory: 965.20 MiB, increment: 7.00 MiB

# %%
q3_memory(file_path)
# Out:
# [('narendramodi', 2265),
#  ('Kisanektamorcha', 1840),
#  ('RakeshTikaitBKU', 1644),
#  ('PMOIndia', 1427),
#  ('RahulGandhi', 1146),
#  ('GretaThunberg', 1048),
#  ('RaviSinghKA', 1019),
#  ('rihanna', 986),
#  ('UNHumanRights', 962),
#  ('meenaharris', 926)]

# %%
# %timeit q3_memory(file_path)
# Out:
# 2.89 s ± 160 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit q3_memory(file_path)
# Out:
# peak memory: 75.05 MiB, increment: 2.02 MiB
